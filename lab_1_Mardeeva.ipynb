# %%
#Лабораторна робота №1. Інсталяція та налаштування Python-середовища

# %%
_Мета:_ _quick start для роботи з python3 у середовищі IDE PyCharm системою контроля версій git._

# %%
1. Завантажила, встановила і налаштувала IDE PyCharm у відповідності з інструкціями, описаними у методичці.

# %%
2. Завантажила, встановила і налаштувала систему контроля версій Git на вашому робочому комп’ютері.

# %%
3. Створила акаунт на GitHub та створила в ньому новий проєкт з іменем Mardeeva_project.

# %%
![1.1](D:\Python_lab)

# %%
4. Створила файл lab_1_Mardeeva.py з кодом, який виводить фразу “Привіт, Мардєєва”.

# %%
![1.2](D:\Python_lab)
# Out:
# "[1.2]" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
##Контрольні запитання
1. У чому відмінність інтерпретатора від компілятора? Python – компілятор чи інтерпретатор?
* Інтерпретатор виконує програмний код рядок за рядком, переводячи його у виконувані інструкції на ходу.
  Компілятор перетворює увесь програмний код у машинний код або виконуваний файл перед запуском програми.
  Python використовує інтерпретатор.
2. Що таке IDE PyCharm?
* PyCharm – це інтегроване середовище розробки, спеціально розроблене для роботи з Python. Воно надає інструменти для редагування коду, відладки, тестування та інших аспектів розробки програм.
3. Що таке система контроля версій (СКВ) і для чого вона призначена? У чому принципова відмінність СКВ SVN та GIT?
* SVN - це централізована система контролю версій, де вся історія змін зберігається на одному центральному сервері.
  GIT -це розподілена система контролю версій, де кожен розробник має повну копію історії змін на своєму комп'ютері. 
4. Що відбувається при виконанні команди 'git add .'?
* додавання всіх новостворених файлів у індекс
5. Що відбувається при виконанні команди 'git commit'?
* додавання змін у локальний Git-репозиторій
6. Якою Git-командою виконується розміщення локальної копії Git-репозиторію проєкта на віддаленому, що знаходиться на GitHub?
* Командою 'Push'
# Out:
#   Cell In[4], line 7
#     * PyCharm – це інтегроване середовище розробки (IDE), спеціально розроблене для роботи з Python. Воно надає інструменти для редагування коду, відладки, тестування та інших аспектів розробки програм.
#               ^
# SyntaxError: invalid character '–' (U+2013)
